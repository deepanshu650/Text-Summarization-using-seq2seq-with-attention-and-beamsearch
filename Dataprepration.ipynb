# %%
import pandas as pd

# %%
data = pd.concat([pd.read_csv(r'/home/deepanshu/Downloads/summary/sumdata/train/train.title.txt' ,sep ="\n"),
                 pd.read_csv(r'/home/deepanshu/Downloads/summary/sumdata/train/train.article.txt' ,sep ="\n")] ,
                axis =1)
data.columns = ["Summary" , "Article"]

# %%
data
# Out:
#                                                    Summary  \
# 0          at least two dead in southern philippines blast
# 1                 australian stocks close down #.# percent
# 2        envoy urges north korea to restart nuclear dis...
# 3           skorea announces tax cuts to stimulate economy
# 4                    taiwan shares close down #.## percent
# ...                                                    ...
# 3803951  duma urges yeltsin to reconsider troop pullout...
# 3803952     us justice department rejects special probe of
# 3803953    un seeks fund for programs in former yugoslavia
# 3803954  chirac gets birthday gift of ##th century african
# 3803955             war crime tribunal passes #st sentence
#
#                                                    Article
# 0        at least two people were killed in a suspected...
# 1        australian shares closed down #.# percent mond...
# 2        south korea 's nuclear envoy kim sook urged no...
# ...

# %%
val = pd.concat([pd.read_csv(r'/home/deepanshu/Downloads/summary/sumdata/train/valid.title.filter.txt' ,sep ="\n"),
                 pd.read_csv(r'/home/deepanshu/Downloads/summary/sumdata/train/valid.article.filter.txt' ,sep ="\n")] ,
                axis =1)
val.columns =["Summary " , "Article"]

# %%
val
# Out:
#                                                  Summary   \
# 0               us business attacks tough immigration law
# 1                       gm december sales fall ## percent
# 2       thousands of croatians celebrate before world ...
# 3       laura bush <unk> rice to attend sirleaf 's ina...
# 4       top republican lobbyist pleads guilty to flori...
# ...                                                   ...
# 189645  thailand 's traffic death toll during holiday ...
# 189646          # killed in blast in southern philippines
# 189647                thailand 's suicide rate falls back
# 189648                nepal announces #### as export year
# 189649  thai scientists succeed in making plants flowe...
#
#                                                   Article
# 0       us business leaders lashed out wednesday at le...
# 1       general motors corp. said wednesday its us sal...
# 2       several thousand people gathered on wednesday ...
# ...

# %%
index1 = 80000
df = data[:index1]
df.to_csv(r'/home/deepanshu/Downloads/GigaTrainSet.csv' , index = False)

# %%
df = pd.read_csv(r'/home/deepanshu/Downloads/GigaTrainSet.csv')
df
# Out:
#                                                  Summary  \
# 0        at least two dead in southern philippines blast
# 1               australian stocks close down #.# percent
# 2      envoy urges north korea to restart nuclear dis...
# 3         skorea announces tax cuts to stimulate economy
# 4                  taiwan shares close down #.## percent
# ...                                                  ...
# 79995              top mafia fugitive arrested in sicily
# 79996  us first lady assures afghans of continued ame...
# 79997               wembley project facing further delay
# 79998      britain 's jack straw to visit india pakistan
# 79999  un confirms it will hold talks with iraq in vi...
#
#                                                  Article
# 0      at least two people were killed in a suspected...
# 1      australian shares closed down #.# percent mond...
# 2      south korea 's nuclear envoy kim sook urged no...
# ...

# %%
index2 = 1000
df = val[:index2]
df.to_csv(r'/home/deepanshu/Downloads/GigaValdSet.csv' , index = False)

# %%
df = pd.read_csv(r'/home/deepanshu/Downloads/GigaValdSet.csv')
df
# Out:
#                                               Summary   \
# 0            us business attacks tough immigration law
# 1                    gm december sales fall ## percent
# 2    thousands of croatians celebrate before world ...
# 3    laura bush <unk> rice to attend sirleaf 's ina...
# 4    top republican lobbyist pleads guilty to flori...
# ..                                                 ...
# 995  us senator urges china to tackle trade issues ...
# 996                       hong kong gold closes higher
# 997       polish new car sales hit ##-year low in ####
# 998  beiersdorf net profit exceeds ### mln euros in...
# 999  french industrial output up #.# percent in nov...
#
#                                                Article
# 0    us business leaders lashed out wednesday at le...
# 1    general motors corp. said wednesday its us sal...
# 2    several thousand people gathered on wednesday ...
# 3    us first lady laura bush and us secretary of s...
# ...
